# %% [markdown]
# ## Python libraries

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from google.colab import drive
from tensorflow.keras import layers

# %% [markdown]
# ## Constants

# %%
MODEL_ALPHA = 0.35
MODEL_INPUT_WIDTH = 48
MODEL_INPUT_HEIGHT = 48
TFL_MODEL_FILE = "model.tflite"
TFL_MODEL_HEADER_FILE = "model.h"
TF_MODEL = "guard_shack_recognition"

# %% [markdown]
# # **Transfer learning with Keras**
# ### Mount the top-level Google Drive directory

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Prepare the train (80%) and validation (20%) datasets

# %%
train_dir = "drive/MyDrive/hackathon/dataset"

ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  validation_split=0.2,
  subset="both",
  seed=123,
  interpolation="bilinear",
  image_size=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT)
  )

train_ds = ds[0]
val_ds   = ds[1]
# Out:
# Found 66 files belonging to 3 classes.
# Using 53 files for training.
# Using 13 files for validation.

# %% [markdown]
# ### Get the number of classes from the training dataset

# %%
class_names = train_ds.class_names
num_classes = len(class_names)
print(class_names)
# Out:
# ['allow', 'call', 'deny']

# %% [markdown]
# ### Rescale the pixel values from [0, 255] tp [-1, 1]

# %%
rescale = tf.keras.layers.Rescaling(1./255, offset= -1)
train_ds = train_ds.map(lambda x, y: (rescale(x), y))
val_ds   = val_ds.map(lambda x, y: (rescale(x), y))

# %% [markdown]
# ### Import the MobileNet v2 pre-trained model

# %%
# https://github.com/keras-team/keras-applications/blob/master/keras_applications/mobilenet_v2.py
base_model = MobileNetV2(input_shape=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT, 3),
                         include_top=False,
                         weights='imagenet',
                         alpha=0.35)
# Out:
# /tmp/ipython-input-1315049705.py:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(input_shape=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT, 3),
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.35_224_no_top.h5
# 2019640/2019640 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ### Freeze the weights

# %%
base_model.trainable = False
feat_extr = base_model

print("num. weights:", len(base_model.weights))
print("num. trainable_weights:", len(base_model.trainable_weights))
print("num. non_trainable_weights:", len(base_model.non_trainable_weights))
# Out:
# num. weights: 260
# num. trainable_weights: 0
# num. non_trainable_weights: 260

# %% [markdown]
# ### Augment the input data

# %%
augmen = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
])

train_ds = train_ds.map(lambda x, y: (augmen(x), y))
val_ds   = val_ds.map(lambda x, y: (augmen(x), y))

# %% [markdown]
# ### Prepare the classification head

# %%
layers = tf.keras.layers
global_avg_layer = layers.GlobalAveragePooling2D()
dense_layer = layers.Dense(num_classes, activation='softmax')

# %% [markdown]
# ### Finalize the model architecture

# %%
x = global_avg_layer(feat_extr.layers[-1].output)
x = layers.Dropout(0.2)(x)
outputs = dense_layer(x)
model = tf.keras.Model(inputs=feat_extr.inputs, outputs=outputs)

# %% [markdown]
# ### Compile the model with a 0.0005 learning rate

# %%
lr = 0.0005
opt_f = tf.keras.optimizers.Adam(learning_rate=lr)
loss_f = tf.losses.SparseCategoricalCrossentropy(from_logits=False)

model.compile(
  optimizer=opt_f,
  loss=loss_f,
  metrics=['accuracy'])

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 48, 48, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 24, 24,    │        432 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 24, 24,    │         64 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 24, 24,    │          0 │ bn_Conv1[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 24, 24,    │        144 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 24, 24,    │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 24, 24,    │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 24, 24, 8) │        128 │ expanded_conv_de… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 24, 24, 8) │         32 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 24, 24,    │        384 │ expanded_conv_pr… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 24, 24,    │        192 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 24, 24,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 25, 25,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 12, 12,    │        432 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 12, 12,    │        192 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 12, 12,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 12, 12, 8) │        384 │ block_1_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 12, 12, 8) │         32 │ block_1_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 12, 12,    │        384 │ block_1_project_… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 12, 12,    │        192 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 12, 12,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 12, 12,    │        432 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 12, 12,    │        192 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 12, 12,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 12, 12, 8) │        384 │ block_2_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 12, 12, 8) │         32 │ block_2_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 12, 12, 8) │          0 │ block_1_project_… │
# │                     │                   │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 12, 12,    │        384 │ block_2_add[0][0] │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 12, 12,    │        192 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 12, 12,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 13, 13,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 6, 6, 48)  │        432 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 6, 6, 48)  │        192 │ block_3_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 6, 6, 48)  │          0 │ block_3_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 6, 6, 16)  │        768 │ block_3_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 6, 6, 16)  │         64 │ block_3_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 6, 6, 96)  │      1,536 │ block_3_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 6, 6, 96)  │        384 │ block_4_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 6, 6, 96)  │          0 │ block_4_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 6, 6, 96)  │        864 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 6, 6, 96)  │        384 │ block_4_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 6, 6, 96)  │          0 │ block_4_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 6, 6, 16)  │      1,536 │ block_4_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 6, 6, 16)  │         64 │ block_4_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 6, 6, 16)  │          0 │ block_3_project_… │
# │                     │                   │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 6, 6, 96)  │      1,536 │ block_4_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 6, 6, 96)  │        384 │ block_5_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 6, 6, 96)  │          0 │ block_5_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 6, 6, 96)  │        864 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 6, 6, 96)  │        384 │ block_5_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 6, 6, 96)  │          0 │ block_5_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 6, 6, 16)  │      1,536 │ block_5_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 6, 6, 16)  │         64 │ block_5_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 6, 6, 16)  │          0 │ block_4_add[0][0… │
# │                     │                   │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 6, 6, 96)  │      1,536 │ block_5_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 6, 6, 96)  │        384 │ block_6_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 6, 6, 96)  │          0 │ block_6_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 7, 7, 96)  │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 3, 3, 96)  │        864 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 3, 3, 96)  │        384 │ block_6_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 3, 3, 96)  │          0 │ block_6_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 3, 3, 24)  │      2,304 │ block_6_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 3, 3, 24)  │         96 │ block_6_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 3, 3, 144) │      3,456 │ block_6_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 3, 3, 144) │        576 │ block_7_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 3, 3, 144) │          0 │ block_7_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 3, 3, 144) │      1,296 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 3, 3, 144) │        576 │ block_7_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 3, 3, 144) │          0 │ block_7_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 3, 3, 24)  │      3,456 │ block_7_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 3, 3, 24)  │         96 │ block_7_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 3, 3, 24)  │          0 │ block_6_project_… │
# │                     │                   │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 3, 3, 144) │      3,456 │ block_7_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 3, 3, 144) │        576 │ block_8_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 3, 3, 144) │          0 │ block_8_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 3, 3, 144) │      1,296 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 3, 3, 144) │        576 │ block_8_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 3, 3, 144) │          0 │ block_8_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 3, 3, 24)  │      3,456 │ block_8_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 3, 3, 24)  │         96 │ block_8_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 3, 3, 24)  │          0 │ block_7_add[0][0… │
# │                     │                   │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 3, 3, 144) │      3,456 │ block_8_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 3, 3, 144) │        576 │ block_9_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 3, 3, 144) │          0 │ block_9_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 3, 3, 144) │      1,296 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 3, 3, 144) │        576 │ block_9_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 3, 3, 144) │          0 │ block_9_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 3, 3, 24)  │      3,456 │ block_9_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 3, 3, 24)  │         96 │ block_9_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 3, 3, 24)  │          0 │ block_8_add[0][0… │
# │                     │                   │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 3, 3, 144) │      3,456 │ block_9_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 3, 3, 144) │        576 │ block_10_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 3, 3, 144) │          0 │ block_10_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 3, 3, 144) │      1,296 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 3, 3, 144) │        576 │ block_10_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 3, 3, 144) │          0 │ block_10_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 3, 3, 32)  │      4,608 │ block_10_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 3, 3, 32)  │        128 │ block_10_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 3, 3, 192) │      6,144 │ block_10_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 3, 3, 192) │        768 │ block_11_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 3, 3, 192) │          0 │ block_11_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 3, 3, 192) │      1,728 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 3, 3, 192) │        768 │ block_11_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 3, 3, 192) │          0 │ block_11_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 3, 3, 32)  │      6,144 │ block_11_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 3, 3, 32)  │        128 │ block_11_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 3, 3, 32)  │          0 │ block_10_project… │
# │                     │                   │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 3, 3, 192) │      6,144 │ block_11_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 3, 3, 192) │        768 │ block_12_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 3, 3, 192) │          0 │ block_12_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 3, 3, 192) │      1,728 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 3, 3, 192) │        768 │ block_12_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 3, 3, 192) │          0 │ block_12_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 3, 3, 32)  │      6,144 │ block_12_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 3, 3, 32)  │        128 │ block_12_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 3, 3, 32)  │          0 │ block_11_add[0][… │
# │                     │                   │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 3, 3, 192) │      6,144 │ block_12_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 3, 3, 192) │        768 │ block_13_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 3, 3, 192) │          0 │ block_13_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 5, 5, 192) │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 2, 2, 192) │      1,728 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 2, 2, 192) │        768 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 2, 2, 192) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 2, 2, 56)  │     10,752 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 2, 2, 56)  │        224 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 2, 2, 336) │     18,816 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 2, 2, 336) │      1,344 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 2, 2, 336) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 2, 2, 336) │      3,024 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 2, 2, 336) │      1,344 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 2, 2, 336) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 2, 2, 56)  │     18,816 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 2, 2, 56)  │        224 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 2, 2, 56)  │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 2, 2, 336) │     18,816 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 2, 2, 336) │      1,344 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 2, 2, 336) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 2, 2, 336) │      3,024 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 2, 2, 336) │      1,344 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 2, 2, 336) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 2, 2, 56)  │     18,816 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 2, 2, 56)  │        224 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 2, 2, 56)  │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 2, 2, 336) │     18,816 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 2, 2, 336) │      1,344 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 2, 2, 336) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 2, 2, 336) │      3,024 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 2, 2, 336) │      1,344 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 2, 2, 336) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 2, 2, 112) │     37,632 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 2, 2, 112) │        448 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 2, 2,      │    143,360 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 2, 2,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 2, 2,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 3)         │      3,843 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 414,051 (1.58 MB)
#  Trainable params: 3,843 (15.01 KB)
#  Non-trainable params: 410,208 (1.56 MB)

# %% [markdown]
# ### Train the model with 10 epochs

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=10
)
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 15s 5s/step - accuracy: 0.1757 - loss: 2.0229 - val_accuracy: 0.3846 - val_loss: 1.5524
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 417ms/step - accuracy: 0.2594 - loss: 1.4252 - val_accuracy: 0.2308 - val_loss: 1.5032
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 455ms/step - accuracy: 0.4456 - loss: 1.1877 - val_accuracy: 0.3077 - val_loss: 1.6567
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 310ms/step - accuracy: 0.2868 - loss: 1.4958 - val_accuracy: 0.4615 - val_loss: 1.1700
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 330ms/step - accuracy: 0.4226 - loss: 1.1903 - val_accuracy: 0.3077 - val_loss: 1.2574
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 0.4855 - loss: 0.9565 - val_accuracy: 0.6154 - val_loss: 1.1125
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step - accuracy: 0.5774 - loss: 0.8505 - val_accuracy: 0.2308 - val_loss: 1.2354
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 384ms/step - accuracy: 0.4833 - loss: 1.1227 - val_accuracy: 0.6923 - val_loss: 0.9681
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 300ms/step - accuracy: 0.4373 - loss: 1.0895 - val_accuracy: 0.6923 - val_loss: 0.9801
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step - accuracy: 0.5293 - loss: 0.9157 - val_accuracy: 0.4615 - val_loss: 0.8977

# %% [markdown]
# ### Export the TensorFlow model

# %%
model.export(TF_MODEL)
# Out:
# Saved artifact at 'guard_shack_recognition'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, 48, 48, 3), dtype=tf.float32, name='keras_tensor')]
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   136247596343056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591556048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591555664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591555472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591553552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591556624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591557200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591556240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591554128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591557008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591557584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591559120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591559312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591558160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591555856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591557968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591561616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591561808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591560656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591560080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591559504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591562960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591563152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591562384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591560272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591562000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591560464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591561424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591562576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591564112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591563536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591563728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591563920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591562768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591565072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591564496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591564688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591564880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591560848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591566032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591566416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591566608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591565264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591566224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591567184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591565840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591565648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591566992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591566800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247591554512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592272528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592271952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592272144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592272336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592273872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592273296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592273488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592273680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592272720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592274832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592274256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592274448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592274640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592272912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592275792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592275216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592275408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592275600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592273104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592276752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247596344208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592276368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592276560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592274064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592277712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592277136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592277328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592277520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592276944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592278672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592278096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592278288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592278480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592275984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592279632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592279056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592279248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592279440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592276176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592280592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592280016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592280208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592280400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592277904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592281552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592280976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592281168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592281360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592278864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592282512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592281936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592282128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592282320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592279824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592283472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592282896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592283088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592283280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592280784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592284432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592283856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592284048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592284240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592281744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592285392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592284816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592285008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592285200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592282704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592286352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592285776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592285968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592286160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592283664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592287312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592286736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592286928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592286544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592288080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592287504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592285584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592287696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592287888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592287120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247592284624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571497232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571497616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571497424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571497808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571498960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571498384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571498576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571498768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571497040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571499920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571499344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571499536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571499728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571498000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571500880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571500304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571500496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571500688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571498192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571501840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571501264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571501456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571501648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571499152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571502800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571502224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571502416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571502608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571500112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571503760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571503184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571503376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571503568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571501072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571504720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571504144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571504336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571504528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571502032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571505680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571505104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571505296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571505488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571502992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571506640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571506064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571506256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571506448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571503952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571507600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571507024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571507216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571507408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571504912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571508560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571507984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571508176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571508368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571505872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571509520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571508944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571509136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571509328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571506832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571510480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571509904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571510096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571510288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571507792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571511440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571510864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571511056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571511248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571508752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571512400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571511824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571512016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571511632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571513168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571512592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571510672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571512784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571512976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571512208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247571509712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468589328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468590480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468590288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468589904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468591056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468589520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468590672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468590864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468589136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468592016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468591440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468591632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468591824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468589712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468592976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468592400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468592592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468592784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468590096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468593936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468593360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468593552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468593744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468591248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468594896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468594320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468594512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468594704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468592208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468595856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468595280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468595472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468595664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468593168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468596816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468596240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468596432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468596624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468594128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468597776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468599120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136247468599696: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# ##**Quantizing and testing the trained model with TensorFlow Lite**
# ### Acquire new images for the test dataset

# %%
# CHANGE TO DESIRED TEST DATASET FOLDER
test_dir = "drive/MyDrive/hackathon/test"

# %% [markdown]
# ### Rescale the pixel values from [0, 255] to [-1, 1]

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(test_dir,
                                                      interpolation="bilinear",
                                                      image_size=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT))
test_ds  = test_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 30 files belonging to 3 classes.

# %% [markdown]
# ### Quantize the TensorFlow model with the TensorFlow Lite converter

# %%
repr_ds = test_ds.unbatch()

def representative_data_gen():
  for i_value, o_value in repr_ds.batch(1).take(48):
    yield [i_value]

converter = tf.lite.TFLiteConverter.from_saved_model(TF_MODEL)
converter.representative_dataset = tf.lite.RepresentativeDataset(representative_data_gen)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8

tfl_model = converter.convert()

# %% [markdown]
# ### Initialize the TensorFlow Lite interpreter

# %%
# Initialize the TFLite interpreter
interp = tf.lite.Interpreter(model_content=tfl_model)
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %% [markdown]
# ### Allocate the tensor and get input quantization parameters

# %%
# Allocate the tensors
interp.allocate_tensors()

# Get input/output layer information
i_details = interp.get_input_details()[0]
o_details = interp.get_output_details()[0]

# Get input quantization parameters.
i_quant = i_details["quantization_parameters"]
i_scale      = i_quant['scales'][0]
i_zero_point = i_quant['zero_points'][0]

# %% [markdown]
# ### Evaluate the accuracy of the quantized TensorFlow Lite model

# %%
test_ds0 = test_ds.unbatch()

num_correct_samples = 0
num_samples   = len(list(test_ds0.batch(1)))

for i_value, o_value in test_ds0.batch(1):
  i_value = (i_value / i_scale) + i_zero_point
  i_value = tf.cast(i_value, dtype=tf.int8)
  interp.set_tensor(i_details["index"], i_value)
  interp.invoke()
  o_pred = interp.get_tensor(o_details["index"])[0]

  if np.argmax(o_pred) == o_value:
    num_correct_samples += 1

print("Accuracy:", num_correct_samples/num_samples)
# Out:
# Accuracy: 0.4

# %% [markdown]
# ### Convert the TensorFlow model to C-byte array with xxd

# %%
open(TFL_MODEL_FILE, "wb").write(tfl_model)
# Out:
# 619840

# %%
# !apt-get update && apt-get -qq install xxd
# Convert the TFLite model to a C source file
# !xxd -c 60 -i {TFL_MODEL_FILE} > {TFL_MODEL_HEADER_FILE}
# !sed -i 's/unsigned char/const unsigned char/g' $TFL_MODEL_HEADER_FILE
# !sed -i 's/const/alignas(8) const/g' $TFL_MODEL_HEADER_FILE
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:4 https://cli.github.com/packages stable InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,123 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,526 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,825 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,969 kB]
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,432 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,594 kB]
# Get:19 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,856 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,168 kB]
# Fetched 37.2 MB in 5s (8,096 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %% [markdown]
# ### Get the TensorFlow model size in bytes to estimate the program memory usage

# %%
size_tfl_model = len(tfl_model)
print(len(tfl_model), "bytes")
# Out:
# 619840 bytes

# %% [markdown]
# ### Convert the Model to TFLite to be used with Microcontrollers

# %%
# Convert the TFLite model to a C source file
# !xxd -i {TFL_MODEL_FILE} > {TFL_MODEL_HEADER_FILE}

# Update the header file name to be a valid C variable name
REPLACEMENT_TEXT = TFL_MODEL_FILE.replace('.', '_')
# !sed -i 's/{REPLACEMENT_TEXT}/{TF_MODEL}/g' {TFL_MODEL_HEADER_FILE}

print(f"TensorFlow Lite model C header file saved to {TFL_MODEL_HEADER_FILE}")
# Out:
# TensorFlow Lite model C header file saved to model.h

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(TF_MODEL)
tflite_model = converter.convert()

with open(TFL_MODEL_FILE, 'wb') as f:
    f.write(tflite_model)

print(f"TensorFlow Lite model saved to {TFL_MODEL_FILE}")
# Out:
# TensorFlow Lite model saved to model.tflite
